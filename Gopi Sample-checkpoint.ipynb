# %% [markdown]
# # Admission Prediction for Student:

# %% [markdown]
# We are predicted to help the Student for admissions depending upon their Score values and Grades for each university/colleges.

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import linear_model,dummy,metrics
from inspect import signature
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
import pickle
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
import os
from pandas.api.types import CategoricalDtype
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import FeatureUnion
from sklearn.model_selection import cross_val_score
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data
ds=pd.read_csv('Admission_Predict.csv')
print(ds)

#DATA ANALYSIS - To check the structure of Data
print(ds.dtypes)
print(ds.info())
print(ds.keys())

# summary statistics
print(ds.describe())

#Missing values check
print(ds.isnull().sum())

# DATA VISUALIZATION TO CHECK THE MISSING VALUES
print(sns.heatmap(ds.isnull()))

print(ds['CGPA'].plot.box())
print(ds['GRE Score'].plot.box())
print(ds['TOEFL Score'].plot.box())
print(ds.plot(kind='box',subplots=True,layout=(4,5)))
print(plt.scatter(ds['Chance of Admit '],ds['GRE Score']))
print(plt.scatter(ds['Chance of Admit '],ds['TOEFL Score']))
print(plt.scatter(ds['Chance of Admit '],ds['University Rating']))
print(plt.scatter(ds['Chance of Admit '],ds['CGPA']))
print(sns.pairplot(ds))

# To check the correlation
dscor=ds.corr()
print(dscor)

# Data visualization
print(sns.heatmap(dscor))

corr_hmap=ds.corr()
print(plt.figure(figsize=(8,7)))
print(sns.heatmap(corr_hmap,annot=True))
print(plt.show())
# Observation: Data cleaning is completed

feature_cols = ['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP','LOR ', 'CGPA', 'Research']
x = ds[feature_cols]
print(x.head())

# check the type and shape of X
print(type(x))
print(x.shape)

y = ds['Chance of Admit ']
print(y.head())

print(x.shape)
print(y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=12)
print('Observation - Your output should appear at this point as:')
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)


lm = LinearRegression()
print(lm.fit(x_train,y_train))

print(lm.coef_)

print(lm.intercept_)

print(lm.score(x_train,y_train))

pred=lm.predict(x_test)
print(pred)

#Scaling the Data
from sklearn.preprocessing import StandardScaler
feature_scaler = StandardScaler()
x_train=feature_scaler.fit_transform(x_train)
y_test=feature_scaler.transform(x_test)

#Training and Cross Validation
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=300,random_state=50)


#Applying Grid SearchCV model
grid_param = {
    'n_estimators': [100,300,500,800,1000],
    'criterion':['gini','entropy'],
    'bootstrap':[True,False]
}

gd_sr = GridSearchCV(estimator = classifier,
                    param_grid=grid_param,
                    scoring='accuracy',
                    cv=3,
                    n_jobs=1)

#Predicted output in 3 number of folds
from sklearn.model_selection import KFold
kf = KFold(n_splits=3)
print(kf)


for train_index , test_index in kf.split([1,2,3,4,5,6,7]):
    print(train_index,test_index)
    
def get_score(model,x_train,x_test,y_train,y_test):
    model.fit(x_train,y_train)
    return model.score(x_test, y_test)

from sklearn.model_selection import StratifiedKFold
folds = StratifiedKFold(n_splits=3)


# Predicting the Future values for admission
pred=lm.predict(x_test)
print("Predicted Results : ", pred)
print("actual price",y_test)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
# Lets save the model for further use
joblib.dump(pred, 'rf_regressor.pkl')
# Out:
# ['rf_regressor.pkl']

# %% [markdown]
# # Output:
# We have built the model to help the students by predicting the Chance of Admission to join the college depends upon their Grades ands marks obtained
#
#                                                         - Gopinath Lakshmanan
#                                                           gopinath28031995@gmail.com
